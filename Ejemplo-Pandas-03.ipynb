# %%
import pandas as pd

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: EAA5-768A
#
#  Directorio de C:\Users\Francisco\Documents\Programaci¢n\Projects_Pythom\Python-basico-03
#
# 12/03/2022  16:27    <DIR>          .
# 12/03/2022  16:27    <DIR>          ..
# 12/03/2022  13:07    <DIR>          .ipynb_checkpoints
# 12/03/2022  16:25    <DIR>          data
# 12/03/2022  13:07    <DIR>          data2
# 12/03/2022  15:29            56.793 Ejemplo-Pandas-01.ipynb
# 12/03/2022  16:25            69.724 Ejemplo-Pandas-02.ipynb
# 12/03/2022  16:27             3.639 Ejemplo-Pandas-03.ipynb
# 12/03/2022  13:07    <DIR>          images
# 12/03/2022  13:07             1.391 README.md
#                4 archivos        131.547 bytes
#                6 dirs  48.757.411.840 bytes libres

# %%
ls .\data2
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: EAA5-768A
#
#  Directorio de C:\Users\Francisco\Documents\Programaci¢n\Projects_Pythom\Python-basico-03\data2
#
# 12/03/2022  13:07    <DIR>          .
# 12/03/2022  13:07    <DIR>          ..
# 12/03/2022  13:07         1.757.369 instituciones_11.json
# 12/03/2022  13:07           576.928 instituciones_19.json
# 12/03/2022  13:07         1.054.589 instituciones_7.json
#                3 archivos      3.388.886 bytes
#                2 dirs  48.757.395.456 bytes libres

# %%
# Antes de ejecutar esta línea de código, explorar el archivo a través de un editor de texto
# leer el archivo json, a través de read_json

datos1 = pd.read_json("data2/instituciones_7.json")
print(datos1.shape) # Tamaño del dataframe datos1
datos2 = pd.read_json("data2/instituciones_11.json")
print(datos2.shape) # Tamaño del dataframe datos1
datos3 = pd.read_json("data2/instituciones_19.json")
print(datos3.shape) # Tamaño del dataframe datos1
datos1.shape[0] + datos2.shape[0] + datos3.shape[0] # Total de filas para el dataframe final
# Out:
# (916, 30)
# (1537, 30)
# (494, 30)
# 2947

# %%
# Ejecutar la línea de código
print(datos1.keys())
# Out:
# Index(['AMIE', 'Nombre_Institucion', 'Codigo_Provincia', 'Provincia',
#        'Codigo_Canton', 'Canton', 'Codigo_Parroquia', 'Parroquia',
#        'Zona_Administrativa', 'Denominacion_Distrito', 'Codigo_Distrito',
#        'Codigo_Circuito_Educativo', 'Unidad_Administrativa_Circuital',
#        'Casos_excepcionales', 'Sostenimiento', 'Regimen_Escolar',
#        'Jurisdiccion', 'Tipo_de_Educacion', 'Modalidad', 'Jornada', 'Nivel',
#        'Etnia', 'Nacionalidad', 'Pueblo', 'Georeferencia',
#        'Institucion_responsable', 'Tipo_Acceso', 'Numero_de_estudiantes',
#        'Numero_de_docentes', 'Estado'],
#       dtype='object')

# %%
# Ejecutar la línea de código
print(datos2.keys())
# Out:
# Index(['AMIE', 'Nombre_Institucion', 'Codigo_Provincia', 'Provincia',
#        'Codigo_Canton', 'Canton', 'Codigo_Parroquia', 'Parroquia',
#        'Zona_Administrativa', 'Denominacion_Distrito', 'Codigo_Distrito',
#        'Codigo_Circuito_Educativo', 'Unidad_Administrativa_Circuital',
#        'Casos_excepcionales', 'Sostenimiento', 'Regimen_Escolar',
#        'Jurisdiccion', 'Tipo_de_Educacion', 'Modalidad', 'Jornada', 'Nivel',
#        'Etnia', 'Nacionalidad', 'Pueblo', 'Georeferencia',
#        'Institucion_responsable', 'Tipo_Acceso', 'Numero_de_estudiantes',
#        'Numero_de_docentes', 'Estado'],
#       dtype='object')

# %%
# Ejecutar la línea de código
print(datos3.keys())
# Out:
# Index(['AMIE', 'Nombre_Institucion', 'Codigo_Provincia', 'Provincia',
#        'Codigo_Canton', 'Canton', 'Codigo_Parroquia', 'Parroquia',
#        'Zona_Administrativa', 'Denominacion_Distrito', 'Codigo_Distrito',
#        'Codigo_Circuito_Educativo', 'Unidad_Administrativa_Circuital',
#        'Casos_excepcionales', 'Sostenimiento', 'Regimen_Escolar',
#        'Jurisdiccion', 'Tipo_de_Educacion', 'Modalidad', 'Jornada', 'Nivel',
#        'Etnia', 'Nacionalidad', 'Pueblo', 'Georeferencia',
#        'Institucion_responsable', 'Tipo_Acceso', 'Numero_de_estudiantes',
#        'Numero_de_docentes', 'Estado'],
#       dtype='object')

# %%
# Analice las salidas anteriores

# %% [markdown]
# ## Retos

# %%
# Ejecutar la siguiente línea de código
lista_dataframes = [datos1, datos2, datos3]
lista_dataframes
# Out:
# [         AMIE                 Nombre_Institucion  Codigo_Provincia Provincia  \
#  0    07H00408          BATALLON CAYAMBE NÚMERO 3                 7    EL ORO
#  1    07H00419                   CORAZON DE JESUS                 7    EL ORO
#  2    07H00404                  ONCE DE NOVIEMBRE                 7    EL ORO
#  3    07H00412                      ASAAD BUCARAM                 7    EL ORO
#  4    07H01432              BIMOT 1  CONSTITUCIÓN                 7    EL ORO
#  ..        ...                                ...               ...       ...
#  911  07H01256          REINALDO ESPINOSA AGUILAR                 7    EL ORO
#  912  07H01258                         5 DE JUNIO                 7    EL ORO
#  913  07H01446                    SAN FRANCISCO 2                 7    EL ORO
#  914  07H01467  CENTRO ARTESANAL GABRIELA MISTRAL                 7    EL ORO
#  915  07H01342                      SAN FRANCISCO                 7    EL ORO
#
#       Codigo_Canton     Canton  Codigo_Parroquia        Parroquia  \
#  0              702  ARENILLAS             70250        ARENILLAS
#  1              702  ARENILLAS             70250        ARENILLAS
#  2              702  ARENILLAS             70250        ARENILLAS
#  3              702  ARENILLAS             70250        ARENILLAS
#  4              702  ARENILLAS             70250        ARENILLAS
#  ..             ...        ...               ...              ...
#  911            713     ZARUMA             71356           MALVAS
#  912            713     ZARUMA             71357  MULUNCAY GRANDE
#  913            713     ZARUMA             71350           ZARUMA
#  914            713     ZARUMA             71350           ZARUMA
#  915            713     ZARUMA             71350           ZARUMA
#
#      Zona_Administrativa               Denominacion_Distrito  ...  \
#  0                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#  1                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#  2                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#  3                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#  4                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#  ..                  ...                                 ...  ...
#  911              Zona 7      ZARUMA – PORTOVELO – ATAHUALPA  ...
#  912              Zona 7      ZARUMA – PORTOVELO – ATAHUALPA  ...
#  913              Zona 7      ZARUMA – PORTOVELO – ATAHUALPA  ...
#  914              Zona 7      ZARUMA – PORTOVELO – ATAHUALPA  ...
#  915              Zona 7      ZARUMA – PORTOVELO – ATAHUALPA  ...
#
#                                        Nivel    Etnia Nacionalidad     Pueblo  \
#  0                          Educación Básica  Mestiza    No aplica  No Aplica
#  1                              Bachillerato  Mestiza    No aplica  No Aplica
#  2                          Educación Básica  Mestiza    No aplica  No Aplica
#  3           Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
#  4    Educación Básica y Alfabetización P.P.  Mestiza    No aplica  No Aplica
#  ..                                      ...      ...          ...        ...
#  911         Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
#  912                        Educación Básica  Mestiza    No aplica  No Aplica
#  913  Educación Básica y Alfabetización P.P.  Mestiza    No aplica  No Aplica
#  914                        Educación Básica  Mestiza         None       None
#  915  Educación Básica y Alfabetización P.P.  Mestiza    No aplica  No Aplica
#
#      Georeferencia Institucion_responsable Tipo_Acceso Numero_de_estudiantes  \
#  0              NO                     1.0   Terrestre                   163
#  1              NO                     1.0   Terrestre                    33
#  2              SI                     3.0   Terrestre                   325
#  3              SI                     3.0   Terrestre                   118
#  4              SI                     3.0   Terrestre                    18
#  ..            ...                     ...         ...                   ...
#  911            SI                     3.0   Terrestre                    55
#  912            SI                     3.0   Terrestre                    90
#  913          None                     NaN   Terrestre                    15
#  914          None                     NaN   Terrestre                    43
#  915          None                     NaN   Terrestre                    15
#
#      Numero_de_docentes  Estado
#  0                   13  Activa
#  1                   11  Activa
#  2                   19  Activa
#  3                   20  Activa
#  4                    1  Activa
#  ..                 ...     ...
#  911                 12  Activa
#  912                  7  Activa
#  913                  0  Activa
#  914                  6  Activa
#  915                  0  Activa
#
#  [916 rows x 30 columns],
#            AMIE                Nombre_Institucion  Codigo_Provincia Provincia  \
#  0     11H01821                      NAUN BRIONES                11      LOJA
#  1     11H00599                  FRANCISCO CHIGUA                11      LOJA
#  2     11H00601            JUAN DE DIOS MALDONADO                11      LOJA
#  3     11H00602              CARLOS CUADRADO LEON                11      LOJA
#  4     11H00603  MANUEL REINALDO TINITANA SARANGO                11      LOJA
#  ...        ...                               ...               ...       ...
#  1532  11H01601               DR. TEODORO SANCHEZ                11      LOJA
#  1533  11H01588                         ZAPOTILLO                11      LOJA
#  1534  11H01589                      FRONTERA SUR                11      LOJA
#  1535  11H01590             FRANCISCO DE ORELLANA                11      LOJA
#  1536  11H01600                 CENTINELA DEL SUR                11      LOJA
#
#        Codigo_Canton     Canton  Codigo_Parroquia  Parroquia  \
#  0              1102     CALVAS            110251  COLAISACA
#  1              1102     CALVAS            110253     UTUANA
#  2              1102     CALVAS            110253     UTUANA
#  3              1102     CALVAS            110253     UTUANA
#  4              1102     CALVAS            110253     UTUANA
#  ...             ...        ...               ...        ...
#  1532           1113  ZAPOTILLO            111353    LIMONES
#  1533           1113  ZAPOTILLO            111353    LIMONES
#  1534           1113  ZAPOTILLO            111353    LIMONES
#  1535           1113  ZAPOTILLO            111353    LIMONES
#  1536           1113  ZAPOTILLO            111353    LIMONES
#
#       Zona_Administrativa          Denominacion_Distrito  ...  \
#  0                 Zona 7                         PALTAS  ...
#  1                 Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
#  2                 Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
#  3                 Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
#  4                 Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
#  ...                  ...                            ...  ...
#  1532              Zona 7                      ZAPOTILLO  ...
#  1533              Zona 7                      ZAPOTILLO  ...
#  1534              Zona 7                      ZAPOTILLO  ...
#  1535              Zona 7                      ZAPOTILLO  ...
#  1536              Zona 7                      ZAPOTILLO  ...
#
#                                  Nivel    Etnia Nacionalidad     Pueblo  \
#  0                    Educación Básica  Mestiza    No aplica  No Aplica
#  1                    Educación Básica  Mestiza    No aplica  No Aplica
#  2                    Educación Básica  Mestiza    No aplica  No Aplica
#  3                    Educación Básica  Mestiza    No aplica  No Aplica
#  4                    Educación Básica  Mestiza    No aplica  No Aplica
#  ...                               ...      ...          ...        ...
#  1532                 Educación Básica  Mestiza    No aplica  No Aplica
#  1533                 Educación Básica  Mestiza    No aplica  No Aplica
#  1534                 Educación Básica  Mestiza    No aplica  No Aplica
#  1535  Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
#  1536                 Educación Básica  Mestiza    No aplica  No Aplica
#
#       Georeferencia Institucion_responsable Tipo_Acceso Numero_de_estudiantes  \
#  0               NO                     0.0   Terrestre                    14
#  1               NO                     1.0   Terrestre                     5
#  2               NO                     1.0   Terrestre                    11
#  3               NO                     1.0   Terrestre                     6
#  4               NO                     1.0   Terrestre                     1
#  ...            ...                     ...         ...                   ...
#  1532            NO                     1.0   Terrestre                     3
#  1533            NO                     1.0   Terrestre                     5
#  1534            NO                     1.0   Terrestre                    10
#  1535            NO                     1.0   Terrestre                   100
#  1536          None                     NaN   Terrestre                     7
#
#       Numero_de_docentes  Estado
#  0                     1  Activa
#  1                     1  Activa
#  2                     1  Activa
#  3                     1  Activa
#  4                     1  Activa
#  ...                 ...     ...
#  1532                  1  Activa
#  1533                  1  Activa
#  1534                  1  Activa
#  1535                 11  Activa
#  1536                  1  Activa
#
#  [1537 rows x 30 columns],
#           AMIE                                 Nombre_Institucion  \
#  0    19H00536                                   MANUEL  BEJARANO
#  1    19H00556  UNIDAD EDUC EXPERIMENTAL A DISTANCIA ZAMORA CH...
#  2    19H00570                      PRIMARIA POPULAR SANTA CLARA
#  3    19H00571                             PRIMARIA POPULAR ZUMBI
#  4    19H00389  UNIDAD EDUC EXPERIMENTAL A DISTANCIA ZAMORA CH...
#  ..        ...                                                ...
#  489  19H00114                                        CARLOS LARA
#  490  19H00115                                  ONCE DE NOVIEMBRE
#  491  19H00004                                  EDELBERTO BONILLA
#  492  19B00001                                      PEDRO KUNANCH
#  493  19H00550                         CREACIONES ROSEMANN ESTILO
#
#       Codigo_Provincia         Provincia  Codigo_Canton                Canton  \
#  0                  19  ZAMORA CHINCHIPE           1907  CENTINELA DEL CONDOR
#  1                  19  ZAMORA CHINCHIPE           1907  CENTINELA DEL CONDOR
#  2                  19  ZAMORA CHINCHIPE           1907  CENTINELA DEL CONDOR
#  3                  19  ZAMORA CHINCHIPE           1907  CENTINELA DEL CONDOR
#  4                  19  ZAMORA CHINCHIPE           1907  CENTINELA DEL CONDOR
#  ..                ...               ...            ...                   ...
#  489                19  ZAMORA CHINCHIPE           1901                ZAMORA
#  490                19  ZAMORA CHINCHIPE           1901                ZAMORA
#  491                19  ZAMORA CHINCHIPE           1901                ZAMORA
#  492                19  ZAMORA CHINCHIPE           1901                ZAMORA
#  493                19  ZAMORA CHINCHIPE           1901                ZAMORA
#
#       Codigo_Parroquia                Parroquia Zona_Administrativa  \
#  0              190752           TRIUNFO-DORADO              Zona 7
#  1              190750                    ZUMBI              Zona 7
#  2              190750                    ZUMBI              Zona 7
#  3              190750                    ZUMBI              Zona 7
#  4              190750                    ZUMBI              Zona 7
#  ..                ...                      ...                 ...
#  489            190158  SAN CARLOS DE LAS MINAS              Zona 7
#  490            190158  SAN CARLOS DE LAS MINAS              Zona 7
#  491            190158  SAN CARLOS DE LAS MINAS              Zona 7
#  492            190151               CUMBARATZA              Zona 7
#  493            190102                   ZAMORA              Zona 7
#
#                              Denominacion_Distrito  ...  \
#  0    NANGARITZA – CENTINELA DEL CÓNDOR – PAQUISHA  ...
#  1    NANGARITZA – CENTINELA DEL CÓNDOR – PAQUISHA  ...
#  2    NANGARITZA – CENTINELA DEL CÓNDOR – PAQUISHA  ...
#  3    NANGARITZA – CENTINELA DEL CÓNDOR – PAQUISHA  ...
#  4    NANGARITZA – CENTINELA DEL CÓNDOR – PAQUISHA  ...
#  ..                                            ...  ...
#  489                             ZAMORA – YACUAMBI  ...
#  490                             ZAMORA – YACUAMBI  ...
#  491                             ZAMORA – YACUAMBI  ...
#  492                             ZAMORA – YACUAMBI  ...
#  493                             ZAMORA – YACUAMBI  ...
#
#                                        Nivel     Etnia Nacionalidad     Pueblo  \
#  0                          Educación Básica   Mestiza    No aplica  No Aplica
#  1           Educación Básica y Bachillerato   Mestiza         None       None
#  2    Educación Básica y Alfabetización P.P.   Mestiza         None       None
#  3                        Alfabetización P.P   Mestiza         None       None
#  4           Educación Básica y Bachillerato   Mestiza    No aplica  No Aplica
#  ..                                      ...       ...          ...        ...
#  489                        Educación Básica   Mestiza    No aplica  No Aplica
#  490                        Educación Básica   Mestiza    No aplica  No Aplica
#  491                        Educación Básica   Mestiza    No aplica  No Aplica
#  492                        Educación Básica  Indígena        Shuar      Shuar
#  493                         No escolarizado   Mestiza    No aplica  No Aplica
#
#      Georeferencia Institucion_responsable Tipo_Acceso Numero_de_estudiantes  \
#  0              NO                     0.0   Terrestre                    12
#  1              NO                     0.0   Terrestre                    47
#  2              NO                     0.0   Terrestre                    14
#  3              NO                     0.0   Terrestre                    15
#  4              NO                     0.0   Terrestre                    80
#  ..            ...                     ...         ...                   ...
#  489            NO                     1.0   Terrestre                    12
#  490            NO                     1.0   Terrestre                    20
#  491            NO                     1.0   Terrestre                     8
#  492            NO                     1.0   Terrestre                     5
#  493          None                     NaN   Terrestre                     0
#
#      Numero_de_docentes  Estado
#  0                    1  Activa
#  1                    6  Activa
#  2                    1  Activa
#  3                    1  Activa
#  4                    6  Activa
#  ..                 ...     ...
#  489                  1  Activa
#  490                  1  Activa
#  491                  1  Activa
#  492                  1  Activa
#  493                  1  Activa
#
#  [494 rows x 30 columns]]

# %%
# Usar la función concat de pandas, 
# el objetivo es unir los dataframes (datos1, datos2 y datos3) en un solo dataframe
dataframe_final = pd.concat(lista_dataframes)
dataframe_final
# Out:
#          AMIE          Nombre_Institucion  Codigo_Provincia         Provincia  \
# 0    07H00408   BATALLON CAYAMBE NÚMERO 3                 7            EL ORO
# 1    07H00419            CORAZON DE JESUS                 7            EL ORO
# 2    07H00404           ONCE DE NOVIEMBRE                 7            EL ORO
# 3    07H00412               ASAAD BUCARAM                 7            EL ORO
# 4    07H01432       BIMOT 1  CONSTITUCIÓN                 7            EL ORO
# ..        ...                         ...               ...               ...
# 489  19H00114                 CARLOS LARA                19  ZAMORA CHINCHIPE
# 490  19H00115           ONCE DE NOVIEMBRE                19  ZAMORA CHINCHIPE
# 491  19H00004           EDELBERTO BONILLA                19  ZAMORA CHINCHIPE
# 492  19B00001               PEDRO KUNANCH                19  ZAMORA CHINCHIPE
# 493  19H00550  CREACIONES ROSEMANN ESTILO                19  ZAMORA CHINCHIPE
#
#      Codigo_Canton     Canton  Codigo_Parroquia                Parroquia  \
# 0              702  ARENILLAS             70250                ARENILLAS
# 1              702  ARENILLAS             70250                ARENILLAS
# 2              702  ARENILLAS             70250                ARENILLAS
# 3              702  ARENILLAS             70250                ARENILLAS
# 4              702  ARENILLAS             70250                ARENILLAS
# ..             ...        ...               ...                      ...
# 489           1901     ZAMORA            190158  SAN CARLOS DE LAS MINAS
# 490           1901     ZAMORA            190158  SAN CARLOS DE LAS MINAS
# 491           1901     ZAMORA            190158  SAN CARLOS DE LAS MINAS
# 492           1901     ZAMORA            190151               CUMBARATZA
# 493           1901     ZAMORA            190102                   ZAMORA
#
#     Zona_Administrativa               Denominacion_Distrito  ...  \
# 0                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 1                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 2                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 3                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 4                Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# ..                  ...                                 ...  ...
# 489              Zona 7                   ZAMORA – YACUAMBI  ...
# 490              Zona 7                   ZAMORA – YACUAMBI  ...
# 491              Zona 7                   ZAMORA – YACUAMBI  ...
# 492              Zona 7                   ZAMORA – YACUAMBI  ...
# 493              Zona 7                   ZAMORA – YACUAMBI  ...
#
#                                       Nivel     Etnia Nacionalidad     Pueblo  \
# 0                          Educación Básica   Mestiza    No aplica  No Aplica
# 1                              Bachillerato   Mestiza    No aplica  No Aplica
# 2                          Educación Básica   Mestiza    No aplica  No Aplica
# 3           Educación Básica y Bachillerato   Mestiza    No aplica  No Aplica
# 4    Educación Básica y Alfabetización P.P.   Mestiza    No aplica  No Aplica
# ..                                      ...       ...          ...        ...
# 489                        Educación Básica   Mestiza    No aplica  No Aplica
# 490                        Educación Básica   Mestiza    No aplica  No Aplica
# 491                        Educación Básica   Mestiza    No aplica  No Aplica
# 492                        Educación Básica  Indígena        Shuar      Shuar
# 493                         No escolarizado   Mestiza    No aplica  No Aplica
#
#     Georeferencia Institucion_responsable Tipo_Acceso Numero_de_estudiantes  \
# 0              NO                     1.0   Terrestre                   163
# 1              NO                     1.0   Terrestre                    33
# 2              SI                     3.0   Terrestre                   325
# 3              SI                     3.0   Terrestre                   118
# 4              SI                     3.0   Terrestre                    18
# ..            ...                     ...         ...                   ...
# 489            NO                     1.0   Terrestre                    12
# 490            NO                     1.0   Terrestre                    20
# 491            NO                     1.0   Terrestre                     8
# 492            NO                     1.0   Terrestre                     5
# 493          None                     NaN   Terrestre                     0
#
#     Numero_de_docentes  Estado
# 0                   13  Activa
# 1                   11  Activa
# 2                   19  Activa
# 3                   20  Activa
# 4                    1  Activa
# ..                 ...     ...
# 489                  1  Activa
# 490                  1  Activa
# 491                  1  Activa
# 492                  1  Activa
# 493                  1  Activa
#
# [2947 rows x 30 columns]

# %%
dataframe_final.shape
# Out:
# (2947, 30)

# %%
dataframe_final.head(10)
# Out:
#        AMIE                       Nombre_Institucion  Codigo_Provincia  \
# 0  07H00408                BATALLON CAYAMBE NÚMERO 3                 7
# 1  07H00419                         CORAZON DE JESUS                 7
# 2  07H00404                        ONCE DE NOVIEMBRE                 7
# 3  07H00412                            ASAAD BUCARAM                 7
# 4  07H01432                    BIMOT 1  CONSTITUCIÓN                 7
# 5  07H01291                     KLEBER TINOCO PINEDA                 7
# 6  07H01305                               LAS BRISAS                 7
# 7  07H01306  CENTRO DE FORMACION ARTESANAL ARENILLAS                 7
# 8  07H01309                          25 DE DICIEMBRE                 7
# 9  07H00397                                 AMAZONAS                 7
#
#   Provincia  Codigo_Canton     Canton  Codigo_Parroquia  Parroquia  \
# 0    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 1    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 2    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 3    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 4    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 5    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 6    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 7    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 8    EL ORO            702  ARENILLAS             70250  ARENILLAS
# 9    EL ORO            702  ARENILLAS             70250  ARENILLAS
#
#   Zona_Administrativa               Denominacion_Distrito  ...  \
# 0              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 1              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 2              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 3              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 4              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 5              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 6              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 7              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 8              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 9              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#
#                                     Nivel    Etnia Nacionalidad     Pueblo  \
# 0                        Educación Básica  Mestiza    No aplica  No Aplica
# 1                            Bachillerato  Mestiza    No aplica  No Aplica
# 2                        Educación Básica  Mestiza    No aplica  No Aplica
# 3         Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
# 4  Educación Básica y Alfabetización P.P.  Mestiza    No aplica  No Aplica
# 5             Inicial y Educacción Básica  Mestiza    No aplica  No Aplica
# 6                        Educación Básica  Mestiza    No aplica  No Aplica
# 7        Educación Básica y Artesanal P.P  Mestiza    No aplica  No Aplica
# 8                        Educación Básica  Mestiza    No aplica  No Aplica
# 9                        Educación Básica  Mestiza    No aplica  No Aplica
#
#   Georeferencia Institucion_responsable Tipo_Acceso Numero_de_estudiantes  \
# 0            NO                     1.0   Terrestre                   163
# 1            NO                     1.0   Terrestre                    33
# 2            SI                     3.0   Terrestre                   325
# 3            SI                     3.0   Terrestre                   118
# 4            SI                     3.0   Terrestre                    18
# 5            SI                     3.0   Terrestre                    66
# 6            SI                     3.0   Terrestre                    96
# 7            SI                     3.0   Terrestre                   301
# 8            SI                     3.0   Terrestre                    54
# 9            SI                     6.0   Terrestre                   121
#
#   Numero_de_docentes  Estado
# 0                 13  Activa
# 1                 11  Activa
# 2                 19  Activa
# 3                 20  Activa
# 4                  1  Activa
# 5                  9  Activa
# 6                  4  Activa
# 7                 17  Activa
# 8                  3  Activa
# 9                  5  Activa
#
# [10 rows x 30 columns]

# %%
# Generar un archivo .json que contenga únicamente las características:
# Nombre_Institucion
# Provincia 
# Sostenimiento
# Jornada
resultado = dataframe_final[['Nombre_Institucion', 'Provincia', 'Sostenimiento', 'Jornada']]

# El archivo debe tener el nombre: instituciones_0003.json, en la carpeta data2

# usa la función .to_json
# Ejemplo: 
# datos.to_json("data/instituciones.json", indent=4, orient="records")
# Donde, datos es un dataframe, 
#        data/instituciones.json, es la ruta y el nombre del archivo
resultado.to_json("data2/instituciones_0003.json", indent=4, orient="records")
resultado
# Out:
#              Nombre_Institucion         Provincia Sostenimiento     Jornada
# 0     BATALLON CAYAMBE NÚMERO 3            EL ORO        Fiscal    Matutina
# 1              CORAZON DE JESUS            EL ORO    Particular  Vespertina
# 2             ONCE DE NOVIEMBRE            EL ORO        Fiscal    Matutina
# 3                 ASAAD BUCARAM            EL ORO        Fiscal    Nocturna
# 4         BIMOT 1  CONSTITUCIÓN            EL ORO        Fiscal    Nocturna
# ..                          ...               ...           ...         ...
# 489                 CARLOS LARA  ZAMORA CHINCHIPE        Fiscal    Matutina
# 490           ONCE DE NOVIEMBRE  ZAMORA CHINCHIPE        Fiscal    Matutina
# 491           EDELBERTO BONILLA  ZAMORA CHINCHIPE        Fiscal    Matutina
# 492               PEDRO KUNANCH  ZAMORA CHINCHIPE        Fiscal    Matutina
# 493  CREACIONES ROSEMANN ESTILO  ZAMORA CHINCHIPE    Particular  Vespertina
#
# [2947 rows x 4 columns]
