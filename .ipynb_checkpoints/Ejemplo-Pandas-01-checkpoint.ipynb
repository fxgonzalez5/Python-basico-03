# %%
import pandas as pd

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: EAA5-768A
#
#  Directorio de C:\Users\Francisco\Documents\Programaci¢n\Projects_Pythom\Python-basico-03
#
# 12/03/2022  13:07    <DIR>          .
# 12/03/2022  13:07    <DIR>          ..
# 12/03/2022  13:07    <DIR>          .ipynb_checkpoints
# 12/03/2022  13:07    <DIR>          data
# 12/03/2022  13:07    <DIR>          data2
# 12/03/2022  13:07             5.999 Ejemplo-Pandas-01.ipynb
# 12/03/2022  13:07             3.510 Ejemplo-Pandas-02.ipynb
# 12/03/2022  13:07             3.804 Ejemplo-Pandas-03.ipynb
# 12/03/2022  13:07    <DIR>          images
# 12/03/2022  13:07             1.391 README.md
#                4 archivos         14.704 bytes
#                6 dirs  70.434.775.040 bytes libres

# %%
ls .\data
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: EAA5-768A
#
#  Directorio de C:\Users\Francisco\Documents\Programaci¢n\Projects_Pythom\Python-basico-03\data
#
# 12/03/2022  13:07    <DIR>          .
# 12/03/2022  13:07    <DIR>          ..
# 12/03/2022  13:07         3.388.882 instituciones_zona_7.json
# 12/03/2022  13:07           782.788 Listado-Instituciones-Educativas-z7.csv
#                2 archivos      4.171.670 bytes
#                2 dirs  70.434.906.112 bytes libres

# %%
# Antes de ejecutar esta línea de código, explorar el archivo a través de un editor de texto
# leer el archivo csv, a través de read_csv
# Además, usamos el parámetro sep="|", debido a que ese caracter es usado como separador de contenido

datos = pd.read_csv("data/Listado-Instituciones-Educativas-z7.csv", sep="|")

# %%
datos.keys()
# Out:
# Index(['Código AMIE', 'Nombre de la Institución Educativa',
#        'Código División Política Administrativa Provincia', 'Provincia',
#        'Código División Política Administrativa  Cantón', 'Cantón',
#        'Código División Política Administrativa  Parroquia', 'Parroquia',
#        'Zona Administrativa', 'Denominación del Distrito',
#        'Código de Distrito', 'Código de Circuito Educativo',
#        ' Unidad Administrativa Circuital (propuesta de ubicación)',
#        'Casos excepcionales', 'Sostenimiento', 'Régimen Escolar',
#        'Jurisdicción', 'Tipo de Educación', 'Modalidad', 'Jornada', 'Nivel',
#        'Etnia', 'Nacionalidad', 'Pueblo',
#        'Institución Educativa georeferenciada', 'Institución responsable',
#        'Acceso (terrestre/ aéreo/fluvial)', 'Número de estudiantes',
#        'Número de docentes', 'Estado'],
#       dtype='object')

# %%
datos.head()
# Out:
#   Código AMIE Nombre de la Institución Educativa  \
# 0    07H00408          BATALLON CAYAMBE NÚMERO 3
# 1    07H00419                   CORAZON DE JESUS
# 2    07H00404                  ONCE DE NOVIEMBRE
# 3    07H00412                      ASAAD BUCARAM
# 4    07H01432              BIMOT 1  CONSTITUCIÓN
#
#    Código División Política Administrativa Provincia Provincia  \
# 0                                                  7    EL ORO
# 1                                                  7    EL ORO
# 2                                                  7    EL ORO
# 3                                                  7    EL ORO
# 4                                                  7    EL ORO
#
#    Código División Política Administrativa  Cantón     Cantón  \
# 0                                              702  ARENILLAS
# 1                                              702  ARENILLAS
# 2                                              702  ARENILLAS
# 3                                              702  ARENILLAS
# 4                                              702  ARENILLAS
#
#    Código División Política Administrativa  Parroquia  Parroquia  \
# 0                                              70250   ARENILLAS
# 1                                              70250   ARENILLAS
# 2                                              70250   ARENILLAS
# 3                                              70250   ARENILLAS
# 4                                              70250   ARENILLAS
#
#   Zona Administrativa           Denominación del Distrito  ...  \
# 0              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 1              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 2              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 3              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 4              Zona 7  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#
#                                     Nivel    Etnia Nacionalidad     Pueblo  \
# 0                        Educación Básica  Mestiza    No aplica  No Aplica
# 1                            Bachillerato  Mestiza    No aplica  No Aplica
# 2                        Educación Básica  Mestiza    No aplica  No Aplica
# 3         Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
# 4  Educación Básica y Alfabetización P.P.  Mestiza    No aplica  No Aplica
#
#   Institución Educativa georeferenciada Institución responsable  \
# 0                                    NO                     1.0
# 1                                    NO                     1.0
# 2                                    SI                     3.0
# 3                                    SI                     3.0
# 4                                    SI                     3.0
#
#   Acceso (terrestre/ aéreo/fluvial) Número de estudiantes Número de docentes  \
# 0                         Terrestre                   163                 13
# 1                         Terrestre                    33                 11
# 2                         Terrestre                   325                 19
# 3                         Terrestre                   118                 20
# 4                         Terrestre                    18                  1
#
#    Estado
# 0  Activa
# 1  Activa
# 2  Activa
# 3  Activa
# 4  Activa
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Retos

# %%
# presentar el número de filas y columnas del dataframe
datos.shape
# Out:
# (2947, 30)

# %%
resultado = datos[['Nombre de la Institución Educativa', 'Provincia']]
# En función del dataframe resultado. Es posible que le ayude realizar un .head para explorar el dataset
resultado.head()
# Out:
#   Nombre de la Institución Educativa Provincia
# 0          BATALLON CAYAMBE NÚMERO 3    EL ORO
# 1                   CORAZON DE JESUS    EL ORO
# 2                  ONCE DE NOVIEMBRE    EL ORO
# 3                      ASAAD BUCARAM    EL ORO
# 4              BIMOT 1  CONSTITUCIÓN    EL ORO

# %%
# Presentar los registros de la provincia de Loja

# %%
resultado[ resultado['Provincia'].str.capitalize() == "Loja" ] # Registros con provincia Loja del dataframe resultado
# Out:
#      Nombre de la Institución Educativa Provincia
# 916                        NAUN BRIONES      LOJA
# 917                    FRANCISCO CHIGUA      LOJA
# 918              JUAN DE DIOS MALDONADO      LOJA
# 919                CARLOS CUADRADO LEON      LOJA
# 920    MANUEL REINALDO TINITANA SARANGO      LOJA
# ...                                 ...       ...
# 2448                DR. TEODORO SANCHEZ      LOJA
# 2449                          ZAPOTILLO      LOJA
# 2450                       FRONTERA SUR      LOJA
# 2451              FRANCISCO DE ORELLANA      LOJA
# 2452                  CENTINELA DEL SUR      LOJA
#
# [1537 rows x 2 columns]

# %%
datos[ datos['Provincia'].str.capitalize() == "Loja" ] # Registros con provincia Loja del dataframe datos
# Out:
#      Código AMIE Nombre de la Institución Educativa  \
# 916     11H01821                       NAUN BRIONES
# 917     11H00599                   FRANCISCO CHIGUA
# 918     11H00601             JUAN DE DIOS MALDONADO
# 919     11H00602               CARLOS CUADRADO LEON
# 920     11H00603   MANUEL REINALDO TINITANA SARANGO
# ...          ...                                ...
# 2448    11H01601                DR. TEODORO SANCHEZ
# 2449    11H01588                          ZAPOTILLO
# 2450    11H01589                       FRONTERA SUR
# 2451    11H01590              FRANCISCO DE ORELLANA
# 2452    11H01600                  CENTINELA DEL SUR
#
#       Código División Política Administrativa Provincia Provincia  \
# 916                                                  11      LOJA
# 917                                                  11      LOJA
# 918                                                  11      LOJA
# 919                                                  11      LOJA
# 920                                                  11      LOJA
# ...                                                 ...       ...
# 2448                                                 11      LOJA
# 2449                                                 11      LOJA
# 2450                                                 11      LOJA
# 2451                                                 11      LOJA
# 2452                                                 11      LOJA
#
#       Código División Política Administrativa  Cantón     Cantón  \
# 916                                              1102     CALVAS
# 917                                              1102     CALVAS
# 918                                              1102     CALVAS
# 919                                              1102     CALVAS
# 920                                              1102     CALVAS
# ...                                               ...        ...
# 2448                                             1113  ZAPOTILLO
# 2449                                             1113  ZAPOTILLO
# 2450                                             1113  ZAPOTILLO
# 2451                                             1113  ZAPOTILLO
# 2452                                             1113  ZAPOTILLO
#
#       Código División Política Administrativa  Parroquia  Parroquia  \
# 916                                              110251   COLAISACA
# 917                                              110253      UTUANA
# 918                                              110253      UTUANA
# 919                                              110253      UTUANA
# 920                                              110253      UTUANA
# ...                                                 ...         ...
# 2448                                             111353     LIMONES
# 2449                                             111353     LIMONES
# 2450                                             111353     LIMONES
# 2451                                             111353     LIMONES
# 2452                                             111353     LIMONES
#
#      Zona Administrativa      Denominación del Distrito  ...  \
# 916               Zona 7                         PALTAS  ...
# 917               Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
# 918               Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
# 919               Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
# 920               Zona 7  GONZANAMÁ – CALVAS – QUILANGA  ...
# ...                  ...                            ...  ...
# 2448              Zona 7                      ZAPOTILLO  ...
# 2449              Zona 7                      ZAPOTILLO  ...
# 2450              Zona 7                      ZAPOTILLO  ...
# 2451              Zona 7                      ZAPOTILLO  ...
# 2452              Zona 7                      ZAPOTILLO  ...
#
#                                 Nivel    Etnia Nacionalidad     Pueblo  \
# 916                  Educación Básica  Mestiza    No aplica  No Aplica
# 917                  Educación Básica  Mestiza    No aplica  No Aplica
# 918                  Educación Básica  Mestiza    No aplica  No Aplica
# 919                  Educación Básica  Mestiza    No aplica  No Aplica
# 920                  Educación Básica  Mestiza    No aplica  No Aplica
# ...                               ...      ...          ...        ...
# 2448                 Educación Básica  Mestiza    No aplica  No Aplica
# 2449                 Educación Básica  Mestiza    No aplica  No Aplica
# 2450                 Educación Básica  Mestiza    No aplica  No Aplica
# 2451  Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
# 2452                 Educación Básica  Mestiza    No aplica  No Aplica
#
#      Institución Educativa georeferenciada Institución responsable  \
# 916                                     NO                     0.0
# 917                                     NO                     1.0
# 918                                     NO                     1.0
# 919                                     NO                     1.0
# 920                                     NO                     1.0
# ...                                    ...                     ...
# 2448                                    NO                     1.0
# 2449                                    NO                     1.0
# 2450                                    NO                     1.0
# 2451                                    NO                     1.0
# 2452                                   NaN                     NaN
#
#      Acceso (terrestre/ aéreo/fluvial) Número de estudiantes  \
# 916                          Terrestre                    14
# 917                          Terrestre                     5
# 918                          Terrestre                    11
# 919                          Terrestre                     6
# 920                          Terrestre                     1
# ...                                ...                   ...
# 2448                         Terrestre                     3
# 2449                         Terrestre                     5
# 2450                         Terrestre                    10
# 2451                         Terrestre                   100
# 2452                         Terrestre                     7
#
#      Número de docentes  Estado
# 916                   1  Activa
# 917                   1  Activa
# 918                   1  Activa
# 919                   1  Activa
# 920                   1  Activa
# ...                 ...     ...
# 2448                  1  Activa
# 2449                  1  Activa
# 2450                  1  Activa
# 2451                 11  Activa
# 2452                  1  Activa
#
# [1537 rows x 30 columns]

# %%
# Exportar el data frame resultado a un archivo .csv, llamado resultado_establecimientos.csv
resultado.to_csv("data/resultado_establecimientos.csv")

# %%
# analice el siguiente código

diccionario_columnas = {'Código AMIE': 'AMIE', 
'Nombre de la Institución Educativa': 'Nombre_Institucion', 
'Código División Política Administrativa Provincia': 'Codigo_Provincia', 
'Provincia': 'Provincia', 
'Código División Política Administrativa  Cantón': 'Codigo_Canton', 
'Cantón': 'Canton', 
'Código División Política Administrativa  Parroquia': 'Codigo_Parroquia', 
'Parroquia': 'Parroquia', 
'Zona Administrativa': 'Zona_Administrativa', 
'Denominación del Distrito': 'Denominacion_Distrito', 
'Código de Distrito': 'Codigo_Distrito', 
'Código de Circuito Educativo': 'Codigo_Circuito_Educativo', 
'Unidad Administrativa Circuital (propuesta de ubicación)': 'Unidad_Administrativa_Circuital', 
'Casos excepcionales': 'Casos_excepcionales', 
'Sostenimiento': 'Sostenimiento', 
'Régimen Escolar': 'Regimen_Escolar', 
'Jurisdicción': 'Jurisdiccion', 
'Tipo de Educación': 'Tipo_de_Educacion', 
'Modalidad': 'Modalidad', 
'Jornada': 'Jornada', 
'Nivel': 'Nivel', 
'Etnia': 'Etnia', 
'Nacionalidad': 'Nacionalidad', 
'Pueblo': 'Pueblo', 
'Institución Educativa georeferenciada': 'Georeferencia', 
'Institución responsable': 'Institucion_responsable', 
'Acceso (terrestre/ aéreo/fluvial)': 'Tipo_Acceso', 
'Número de estudiantes': 'Numero_de_estudiantes', 
'Número de docentes': 'Numero_de_docentes', 
'Estado': 'Estado'}

for d in diccionario_columnas:
    print(diccionario_columnas[d])

lista_columnas = []
for d in diccionario_columnas:
    lista_columnas.append(diccionario_columnas[d])
# Out:
# AMIE
# Nombre_Institucion
# Codigo_Provincia
# Provincia
# Codigo_Canton
# Canton
# Codigo_Parroquia
# Parroquia
# Zona_Administrativa
# Denominacion_Distrito
# Codigo_Distrito
# Codigo_Circuito_Educativo
# Unidad_Administrativa_Circuital
# Casos_excepcionales
# Sostenimiento
# Regimen_Escolar
# Jurisdiccion
# Tipo_de_Educacion
# Modalidad
# Jornada
# Nivel
# Etnia
# Nacionalidad
# Pueblo
# Georeferencia
# Institucion_responsable
# Tipo_Acceso
# Numero_de_estudiantes
# Numero_de_docentes
# Estado

# %%
# cambiar los nombres de las columnas del dataframe datos
# actuales nombres de columnas
print("Nombre de columnas actuales")
print(datos.keys())
# Nombre de columnas para actualizar
print("---------------------------------------")
print("Nombre de columnas para actualizar")
print(lista_columnas)
# Out:
# Nombre de columnas actuales
# Index(['Código AMIE', 'Nombre de la Institución Educativa',
#        'Código División Política Administrativa Provincia', 'Provincia',
#        'Código División Política Administrativa  Cantón', 'Cantón',
#        'Código División Política Administrativa  Parroquia', 'Parroquia',
#        'Zona Administrativa', 'Denominación del Distrito',
#        'Código de Distrito', 'Código de Circuito Educativo',
#        ' Unidad Administrativa Circuital (propuesta de ubicación)',
#        'Casos excepcionales', 'Sostenimiento', 'Régimen Escolar',
#        'Jurisdicción', 'Tipo de Educación', 'Modalidad', 'Jornada', 'Nivel',
#        'Etnia', 'Nacionalidad', 'Pueblo',
#        'Institución Educativa georeferenciada', 'Institución responsable',
#        'Acceso (terrestre/ aéreo/fluvial)', 'Número de estudiantes',
#        'Número de docentes', 'Estado'],
#       dtype='object')
# ---------------------------------------
# Nombre de columnas para actualizar
# ['AMIE', 'Nombre_Institucion', 'Codigo_Provincia', 'Provincia', 'Codigo_Canton', 'Canton', 'Codigo_Parroquia', 'Parroquia', 'Zona_Administrativa', 'Denominacion_Distrito', 'Codigo_Distrito', 'Codigo_Circuito_Educativo', 'Unidad_Administrativa_Circuital', 'Casos_excepcionales', 'Sostenimiento', 'Regimen_Escolar', 'Jurisdiccion', 'Tipo_de_Educacion', 'Modalidad', 'Jornada', 'Nivel', 'Etnia', 'Nacionalidad', 'Pueblo', 'Georeferencia', 'Institucion_responsable', 'Tipo_Acceso', 'Numero_de_estudiantes', 'Numero_de_docentes', 'Estado']

# %%
# ejecutar la siguiente línea de código
datos.columns = lista_columnas

# %%
# explorar el dataframe datos a través de .head
datos.head()
# Out:
#        AMIE         Nombre_Institucion  Codigo_Provincia Provincia  \
# 0  07H00408  BATALLON CAYAMBE NÚMERO 3                 7    EL ORO
# 1  07H00419           CORAZON DE JESUS                 7    EL ORO
# 2  07H00404          ONCE DE NOVIEMBRE                 7    EL ORO
# 3  07H00412              ASAAD BUCARAM                 7    EL ORO
# 4  07H01432      BIMOT 1  CONSTITUCIÓN                 7    EL ORO
#
#    Codigo_Canton     Canton  Codigo_Parroquia  Parroquia Zona_Administrativa  \
# 0            702  ARENILLAS             70250  ARENILLAS              Zona 7
# 1            702  ARENILLAS             70250  ARENILLAS              Zona 7
# 2            702  ARENILLAS             70250  ARENILLAS              Zona 7
# 3            702  ARENILLAS             70250  ARENILLAS              Zona 7
# 4            702  ARENILLAS             70250  ARENILLAS              Zona 7
#
#                 Denominacion_Distrito  ...  \
# 0  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 1  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 2  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 3  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
# 4  ARENILLAS – LAS LAJAS – HUAQUILLAS  ...
#
#                                     Nivel    Etnia Nacionalidad     Pueblo  \
# 0                        Educación Básica  Mestiza    No aplica  No Aplica
# 1                            Bachillerato  Mestiza    No aplica  No Aplica
# 2                        Educación Básica  Mestiza    No aplica  No Aplica
# 3         Educación Básica y Bachillerato  Mestiza    No aplica  No Aplica
# 4  Educación Básica y Alfabetización P.P.  Mestiza    No aplica  No Aplica
#
#   Georeferencia Institucion_responsable Tipo_Acceso Numero_de_estudiantes  \
# 0            NO                     1.0   Terrestre                   163
# 1            NO                     1.0   Terrestre                    33
# 2            SI                     3.0   Terrestre                   325
# 3            SI                     3.0   Terrestre                   118
# 4            SI                     3.0   Terrestre                    18
#
#   Numero_de_docentes  Estado
# 0                 13  Activa
# 1                 11  Activa
# 2                 19  Activa
# 3                 20  Activa
# 4                  1  Activa
#
# [5 rows x 30 columns]

# %%
# presentar los nuevos nombres del dataframe datos
datos.keys()
# Out:
# Index(['AMIE', 'Nombre_Institucion', 'Codigo_Provincia', 'Provincia',
#        'Codigo_Canton', 'Canton', 'Codigo_Parroquia', 'Parroquia',
#        'Zona_Administrativa', 'Denominacion_Distrito', 'Codigo_Distrito',
#        'Codigo_Circuito_Educativo', 'Unidad_Administrativa_Circuital',
#        'Casos_excepcionales', 'Sostenimiento', 'Regimen_Escolar',
#        'Jurisdiccion', 'Tipo_de_Educacion', 'Modalidad', 'Jornada', 'Nivel',
#        'Etnia', 'Nacionalidad', 'Pueblo', 'Georeferencia',
#        'Institucion_responsable', 'Tipo_Acceso', 'Numero_de_estudiantes',
#        'Numero_de_docentes', 'Estado'],
#       dtype='object')
